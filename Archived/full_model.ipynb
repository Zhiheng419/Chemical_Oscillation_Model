# %%
import numpy as np 
import scipy as sp 
import matplotlib.pyplot as plt
import pandas as pd
from osc_toolkit import oscillation
from models import *
from functools import partial

# %%
params = [24.30616411,  1.1391591, 3.08829181, 10.66927823, 0]
consts = [0.17, 4, 1e-1]
init_cond = [0, 0, 0.3]

full_model = oscillation(full_model_FTC, params, consts, init_cond, calc_all_full_model_FTC)
full_model.info
# Out:
# The model includes 5 parameters and 3 constants. The species are ['A2', 'S_sum', 'A', 'O']. Initial condition: [0, 0, 0.3]
# Additional information: None

# %%
params = [24.30616411,  1.1391591,   3.08829181, 10.66927823]
consts = [0.17, 4]
init_cond = [0, 0]
approx_model = oscillation(approx_model_FTC, params, consts, init_cond, calc_all_approx_model_FTC)

# %%
fig, ax = full_model.plot(method='RK45', t=5)
fig.suptitle('Full model')
fig.tight_layout()

# %%
fig, ax = approx_model.plot(method='RK45', t=5)
fig.suptitle('Quasi-steady state approximation')
fig.tight_layout()
