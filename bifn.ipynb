# %%
import numpy as np 
import scipy as sp 
import matplotlib.pyplot as plt
import pandas as pd
from osc_toolkit import oscillation
from models import *

# %%
df_400uL_700rpm = pd.read_csv(r'C:\Users\chem-sedm6967\OneDrive - Nexus365\Desktop\01_projects\01_oscillation modelling\Chemical_Oscillation_Model\Data_sets\C81_400uL_700_LM.csv')
df_400uL_700rpm = df_400uL_700rpm.clip(lower=0)

#Normalization
cmc = 0.22
cA2_sum0 = 14.5
tau = 0.26

df_400uL_700rpm['cA2'] /= cA2_sum0
df_400uL_700rpm['cS'] /= cmc
df_400uL_700rpm[['tA2', 'tS']] /= 60 * tau

params = np.array([1.4, 2, 1.2, 37.1])
consts = np.array([0.015, 2])
init_cond = ([df_400uL_700rpm['cA2'].iloc[0], 0])
osc_400uL_700rpm = oscillation(approx_model_FTC, params, consts, init_cond, calc_all_approx_model_FTC)
osc_400uL_700rpm.add_exp_data(df_400uL_700rpm)
# Out:
# The species are ['A2', 'S_sum', 'A', 'O']. Please check if the data is in the same order and correct format (time, concentration).

# %%
osc_400uL_700rpm.interactive_plot(t=5, ran=20, step=0.02, exp=True)
# Out:
# interactive(children=(FloatSlider(value=1.4, description='alpha', max=21.4, step=0.02), FloatSlider(value=2.0,…

# %%
osc_400uL_700rpm.plot(t=5)
# Out:
# (<Figure size 700x500 with 4 Axes>,
#  <Axes: xlabel='Normalized Time', ylabel='Normalized Concentration'>)

# %%
df_90uL_600rpm = pd.read_csv(r'C:\Users\chem-sedm6967\OneDrive - Nexus365\Desktop\01_projects\01_oscillation modelling\Chemical_Oscillation_Model\Data_sets\C81_90uL_600_LM.csv')
df_90uL_600rpm = df_90uL_600rpm.clip(lower=0)

#Normalization
cmc = 0.22
cA2_sum0 = 14.5
tau = 1.15

df_90uL_600rpm['cA2'] /= cA2_sum0
df_90uL_600rpm['cS'] /= cmc
df_90uL_600rpm[['tA2', 'tS']] /= 60 * tau

params = np.array([ 4.053e+01  ,1.123e-01  ,5.609e+00  ,1.436e+01])
consts = np.array([0.015, 3])
init_cond = ([df_90uL_600rpm['cA2'].iloc[0], 0])
osc_90uL_600rpm = oscillation(approx_model_FTC, params, consts, init_cond, calc_all_approx_model_FTC)
osc_90uL_600rpm.add_exp_data(df_90uL_600rpm)
# Out:
# The species are ['A2', 'S_sum', 'A', 'O']. Please check if the data is in the same order and correct format (time, concentration).

# %%
osc_90uL_600rpm.plot(t=1, exp=True)
# Out:
# (<Figure size 500x500 with 2 Axes>,
#  <Axes: xlabel='Normalized Time', ylabel='Normalized Concentration'>)

# %%
osc_90uL_600rpm.interactive_plot(t=0.5, ran=120, step=0.1)
# Out:
# interactive(children=(FloatSlider(value=40.53, description='alpha', max=160.53), FloatSlider(value=0.1123, des…

# %%
osc_90uL_600rpm.fit(plot=True, overwrite=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 osc_90uL_600rpm.fit(plot=True, overwrite=True)
#
# File c:\Users\chem-sedm6967\OneDrive - Nexus365\Desktop\01_projects\01_oscillation modelling\Chemical_Oscillation_Model\osc_toolkit.py:158, in oscillation.fit(self, plot, overwrite)
#     154     return obj
#     156 params_old = self.__params
# --> 158 opt_result = sp.optimize.minimize(
#     159     objective, self.__params, method='Nelder-Mead', tol=1e-6, options={'maxiter': 1000})
#     160 print(
#     161     f'alpha = {self.__params[0]:.3f}, beta = {self.__params[1]:.3f}, theta = {self.__params[2]:.3f}, phi = {self.__params[3]:.3f}')
#     163 if plot == True:
#
# ...
