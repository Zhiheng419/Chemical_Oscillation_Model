# %%
import numpy as np 
import scipy as sp 
import matplotlib.pyplot as plt
import pandas as pd
from osc_toolkit import oscillation
from models import *

# %%
df_400uL_700rpm = pd.read_csv(r'Data_sets/C81_400uL_700_LM.csv')
df_400uL_700rpm = df_400uL_700rpm.clip(lower=0)

#Normalization
cmc = 0.22
cA2_sum0 = 14.5
tau = 0.26

df_400uL_700rpm['cA2'] /= cA2_sum0
df_400uL_700rpm['cS'] /= cmc
df_400uL_700rpm[['tA2', 'tS']] /= 60 * tau

params = np.array([1.28, 3.78, 2.02, 48.2])
consts = np.array([0.015, 3])
init_cond = ([df_400uL_700rpm['cA2'].iloc[0], 0])
osc_400uL_700rpm = oscillation(approx_model_FTC, params, consts, init_cond, calc_all_approx_model_FTC)
osc_400uL_700rpm.add_exp_data(df_400uL_700rpm)
# Out:
# The species are ['A2', 'S_sum', 'A', 'O']. Please check if the data is in the same order and correct format (time, concentration).

# %%
osc_400uL_700rpm.fit(plot=True, overwrite=True)
# Out:
# alpha = 1.019, beta = -0.000, theta = 4.101, phi = 49.530
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 1021.979480399912
#              x: [ 1.019e+00 -5.236e-10  4.101e+00  4.953e+01]
#            nit: 946
#           nfev: 1644
#  final_simplex: (array([[ 1.019e+00, -5.236e-10,  4.101e+00,  4.953e+01],
#                        [ 1.019e+00, -5.209e-10,  4.101e+00,  4.953e+01],
#                        ...,
#                        [ 1.019e+00, -5.314e-10,  4.101e+00,  4.953e+01],
#                        [ 1.019e+00, -5.206e-10,  4.101e+00,  4.953e+01]]), array([ 1.022e+03,  1.022e+03,  1.022e+03,  1.022e+03,
#                         1.022e+03]))

# %%
osc_400uL_700rpm.interactive_plot(t=5, ran=20, step=0.02, exp=True)
# Out:
# interactive(children=(FloatSlider(value=1.28, description='alpha', max=21.28, step=0.02), FloatSlider(value=3.…

# %%
osc_400uL_700rpm.plot(t=5)
# Out:
# (<Figure size 700x500 with 4 Axes>,
#  <Axes: xlabel='Normalized Time', ylabel='Normalized Concentration'>)

# %%
df_90uL_600rpm = pd.read_csv(r'Data_sets/C81_90uL_600_LM.csv')
df_90uL_600rpm = df_90uL_600rpm.clip(lower=0)

#Normalization
cmc = 0.22
cA2_sum0 = 14.5
tau = 1.15

df_90uL_600rpm['cA2'] /= cA2_sum0
df_90uL_600rpm['cS'] /= cmc
df_90uL_600rpm[['tA2', 'tS']] /= 60 * tau

params = np.array([ 70 ,78  ,8  ,138])
consts = np.array([0.015, 3])
init_cond = ([df_90uL_600rpm['cA2'].iloc[0], 0])
osc_90uL_600rpm = oscillation(approx_model_FTC, params, consts, init_cond, calc_all_approx_model_FTC)
osc_90uL_600rpm.add_exp_data(df_90uL_600rpm)
# Out:
# The species are ['A2', 'S_sum', 'A', 'O']. Please check if the data is in the same order and correct format (time, concentration).

# %%
osc_90uL_600rpm.interactive_plot(t=0.5, ran=20, step=0.1, exp=True)
# Out:
# interactive(children=(FloatSlider(value=82.50627193173926, description='alpha', max=102.50627193173926, min=62…

# %%
osc_90uL_600rpm.fit(plot=True, overwrite=True)
# Out:
# alpha = 82.506, beta = -0.000, theta = 11.830, phi = 148.768
#        message: Optimization terminated successfully.
#        success: True
#         status: 0
#            fun: 23.289011188050235
#              x: [ 8.251e+01 -5.833e-12  1.183e+01  1.488e+02]
#            nit: 316
#           nfev: 556
#  final_simplex: (array([[ 8.251e+01, -5.833e-12,  1.183e+01,  1.488e+02],
#                        [ 8.251e+01, -1.014e-11,  1.183e+01,  1.488e+02],
#                        ...,
#                        [ 8.251e+01, -1.153e-11,  1.183e+01,  1.488e+02],
#                        [ 8.251e+01, -1.026e-11,  1.183e+01,  1.488e+02]]), array([ 2.329e+01,  2.329e+01,  2.329e+01,  2.329e+01,
#                         2.329e+01]))
